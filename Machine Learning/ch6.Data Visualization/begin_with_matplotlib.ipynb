# %% [markdown]
# <div align=center style="line-height:200%;font-family:vazir;font-size:medium;color:#0099cc">
# <h1>
# شروع کار با مت‌پلات
# </h1>
# </p>
# </div>

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(1400)

# %%
# %matplotlib inline

# %%
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x), linestyle='solid')
plt.plot(x, np.cos(x), linestyle='dashed');

# %%
# !pip show matplotlib
# Out:
# Name: matplotlib
# Version: 3.4.2
# Summary: Python plotting package
# Home-page: https://matplotlib.org
# Author: John D. Hunter, Michael Droettboom
# Author-email: matplotlib-users@python.org
# License: PSF
# Location: /home/mohammad/Mohammad/Uni-Spring 02/ML College/qenv/lib/python3.9/site-packages
# Requires: cycler, kiwisolver, numpy, pillow, pyparsing, python-dateutil
# Required-by: seaborn

# %%
fig = plt.figure()

# %%
plt.figure() # یک شکل می‌سازد
plt.axes() # یک صفحه محور استاندارد داخل شکل اخیر می‌سازد
plt.plot(x, np.exp(x))
plt.axes([0.2, 0.4, 0.5, 0.3]) # در لیست مختصات نقطه پایین چپ و طول و عرض صفحه محور نسبت به ابعاد شکل قرار گرفته‌اند
plt.plot(x, np.log(x), color='red', linestyle='dashed')
# Out:
# /tmp/ipykernel_30712/1927047106.py:5: RuntimeWarning: divide by zero encountered in log
#   plt.plot(x, np.log(x), color='red', linestyle='dashed')

# %%
plt.subplot(2, 2, 1)
plt.plot(x, np.sin(x))
plt.subplot(2, 2, 2)
plt.plot(x, np.cos(x), linestyle='dashdot', color='red')
plt.subplot(2, 2, 3)
plt.plot(x, np.exp(x), color='green', linestyle='dashed')
plt.subplot(2, 2, 4)
plt.plot(x, x**2, color='magenta')

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
ax2 = fig.add_axes([0.2, 0.4, 0.5, 0.3])
ax1.plot(x, np.exp(x))
ax2.plot(x, np.log(x), color='red', linestyle='dashed')
# Out:
# /tmp/ipykernel_30712/485026401.py:5: RuntimeWarning: divide by zero encountered in log
#   ax2.plot(x, np.log(x), color='red', linestyle='dashed')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)
ax1.plot(x, np.sin(x))
ax2.plot(x, np.cos(x), color='red', linestyle='dashdot')
ax3.plot(x, np.exp(x), color='green', linestyle='dashed')
ax4.plot(x, x**2, color='magenta', linestyle='solid')

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
for i in range(2):
    for j in range(3):
        ax[i, j].plot(np.random.randint(0,10,20), linestyle = 'solid')
fig
